# %%
#0-means patient is non dibetic
#1 shows person is diabteic

# %%
#pandas for data manipulation or data wrangling
import pandas as pd
#numpy for calculation
import numpy as np

# %%
df=pd.read_csv('diabetics.csv')
df
# Out:
#      Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148              72             35        0  33.6
# 1              1       85              66             29        0  26.6
# 2              8      183              64              0        0  23.3
# 3              1       89              66             23       94  28.1
# 4              0      137              40             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763           10      101              76             48      180  32.9
# 764            2      122              70             27        0  36.8
# 765            5      121              72             23      112  26.2
# 766            1      126              60              0        0  30.1
# 767            1       93              70             31        0  30.4
#
#      DiabetiesPedegreeFunction  Age  Outcome
# 0                        0.627   50        1
# ...

# %%
#to know the type of datastructure of the table
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148              72             35        0  33.6
# 1            1       85              66             29        0  26.6
# 2            8      183              64              0        0  23.3
# 3            1       89              66             23       94  28.1
# 4            0      137              40             35      168  43.1
#
#    DiabetiesPedegreeFunction  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101              76             48      180  32.9
# 764            2      122              70             27        0  36.8
# 765            5      121              72             23      112  26.2
# 766            1      126              60              0        0  30.1
# 767            1       93              70             31        0  30.4
#
#      DiabetiesPedegreeFunction  Age  Outcome
# 763                      0.171   63        0
# 764                      0.340   27        0
# 765                      0.245   30        0
# 766                      0.349   47        1
# 767                      0.315   23        0

# %%
df.sample(2)
# Out:
#      Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin   BMI  \
# 443            8      108              70              0        0  30.5
# 753            0      181              88             44      510  43.3
#
#      DiabetiesPedegreeFunction  Age  Outcome
# 443                      0.955   33        1
# 753                      0.222   26        1

# %%
# to check the columns in the data set
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', ' BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetiesPedegreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (768, 9)

# %%
# to check the null values.this will give the boolean values

df.isnull()
# Out:
#      Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False           False          False    False  False
# 1          False    False           False          False    False  False
# 2          False    False           False          False    False  False
# 3          False    False           False          False    False  False
# 4          False    False           False          False    False  False
# ..           ...      ...             ...            ...      ...    ...
# 763        False    False           False          False    False  False
# 764        False    False           False          False    False  False
# 765        False    False           False          False    False  False
# 766        False    False           False          False    False  False
# 767        False    False           False          False    False  False
#
#      DiabetiesPedegreeFunction    Age  Outcome
# ...

# %%
#column wise sum
df.isnull().sum()
# Out:
# Pregnancies                  0
# Glucose                      0
#  BloodPressure               0
# SkinThickness                0
# Insulin                      0
# BMI                          0
# DiabetiesPedegreeFunction    0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
#this will tell the total number of null values present in the Dataset
df.isnull().sum().sum()
# Out:
# 0

# %%
#if there were null values we need to impute them or drop them.
# simple way of imutation-if the column is categorical then mode/frequency
#if the data is numerical column then mean/medain

# %%
#there are otehr type of imputers like-knn imputer,simple imputer(these are univariate imputers),iterative imputer is mulrtivariate imputer

# %%
#if u want to fill the null values
#df['DiabetiesPedegreeFunction'].fillna(value = df['DiabetiesPedegreeFunction'].mean())

# %%
#to check & drop duplicates in the data
df.drop_duplicates()
# Out:
#      Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148              72             35        0  33.6
# 1              1       85              66             29        0  26.6
# 2              8      183              64              0        0  23.3
# 3              1       89              66             23       94  28.1
# 4              0      137              40             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763           10      101              76             48      180  32.9
# 764            2      122              70             27        0  36.8
# 765            5      121              72             23      112  26.2
# 766            1      126              60              0        0  30.1
# 767            1       93              70             31        0  30.4
#
#      DiabetiesPedegreeFunction  Age  Outcome
# 0                        0.627   50        1
# ...

# %%
#here no duplicates in the data

# %% [markdown]
# EDA

# %%
#Descriptive Analysis which will give the description of the data-mean,median,mode,SD, percentile,quantile
#Null value Analysis-if any column has more than 50% missing data then its advisable to drop the column rather than fill out the data.
#Plotting of the data by Visualisation,univariate analysis(boxplot,density(histogram,kde)),bivariate(scatter plot),multivariate(pairplots,heatmap)
#Hirerarichal visualisation -to check hirerachy in the darta
#correlation-to find the correlation between the target variable & every other input column /causation
# (i think is dropping some columns which ndt contribute to y or where lots of columns are there)
#Distribution of data -Skewness,kutosis (vertically distributed),moments,momentum

# %%
Machine learning pre requiste
    Data shud be normally distributed
    Data shud not contain any outliers
    data shud be in the same scale
    no null values
    data is commonly scaled

# %%
#independent features--all columns shud be having normal distribution,skewness shud be removed using teansformation method
#no outliers-identify if any outliers are there. by zscore or IQR,boxplot works on the priciple of percentile
#bring DS to the same scale. for this we will use normalisation (data gets scales from 1 infitinity to +infinity)or standardisation(mean is 0 & SD will be 1) techniques

# %% [markdown]
# #we use scatterplot for analysing he data because it helps us to knwo the contribution oif each column to the outcome.

# %% [markdown]
# Analysing the Data

# %%
# we will import seaborn module to do the bivaraite analysis thru scatterplot
import seaborn as sns

# %%
sns.scatterplot(x='Pregnancies',y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Outcome'>

# %%
#data is equally distributed. this type of distribution is require for ML else bias will be created from these columns
#%0% data is 0 and 50% is 1
#any patiebn is there who is above 13 weeks pregnant is diabetic
#observation-We can see the no. of weeks of pregnancies is equally distributed in the range 0 to 13

# %%
sns.scatterplot(x='Glucose',y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Outcome'>

# %% [markdown]
# #we can see that glucose is equally distributed in the range 0 to 200

# %%
sns.scatterplot(x='SkinThickness',y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Outcome'>

# %% [markdown]
# #this scatterplot means this column is contributing almost equal 0 and 1s to y
# #observation #we can see that skin Thickness is equally distributed in the range 5 to 55

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', ' BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetiesPedegreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.scatterplot(x='Insulin',y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Outcome'>

# %%
##we can see that insulin is equally distributed in the range 0 to 400

# %%
sns.scatterplot(x='BMI',y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Outcome'>

# %%
#we can see that BMIis equally distributed in the range 25 to 50

# %%
sns.scatterplot(x='DiabetiesPedegreeFunction',y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='DiabetiesPedegreeFunction', ylabel='Outcome'>

# %%
#we can see that Diabeticpedegree function is equally distributed in the range 0 to 1.5

# %%
sns.scatterplot(x='Age',y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Outcome'>

# %%
sns.scatterplot(x=' BloodPressure',y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel=' BloodPressure', ylabel='Outcome'>

# %% [markdown]
# #we can see that BP is equally distributed in the range 45 to 100

# %% [markdown]
# MultiVaraite Analysis Using Pairplot

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
#to save the pairplot in the local drive 
plt.savefig('pairplot.png')

plt.show()

# %%
#Column VS Column distribution
#9 columns so 9 * 9 =81 pair plots
1st graph down left is preganacy vs outcome,then pregancy vs age
#Whenever same column is compared to same colum outcom vs outcome we get a histogram.

# %% [markdown]
# Next is to Find the correlation between the columns

# %% [markdown]
# Correlation

# %%
df.corr()
# Out:
#                            Pregnancies   Glucose   BloodPressure  \
# Pregnancies                   1.000000  0.129459        0.141282
# Glucose                       0.129459  1.000000        0.152590
#  BloodPressure                0.141282  0.152590        1.000000
# SkinThickness                -0.081672  0.057328        0.207371
# Insulin                      -0.073535  0.331357        0.088933
# BMI                           0.017683  0.221071        0.281805
# DiabetiesPedegreeFunction    -0.033523  0.137337        0.041265
# Age                           0.544341  0.263514        0.239528
# Outcome                       0.221898  0.466581        0.065068
#
#                            SkinThickness   Insulin       BMI  \
# Pregnancies                    -0.081672 -0.073535  0.017683
# Glucose                         0.057328  0.331357  0.221071
#  BloodPressure                  0.207371  0.088933  0.281805
# SkinThickness                   1.000000  0.436783  0.392573
# ...

# %%
#same column vs same column correlation will be 1 eg 1st column
#this is a diagonal matrix as glucose vs pregnancy is the smae when pregnancy vs glucose
#if the number of columns are mre eg 100..its better to use a heat map to show the correation.

# %%
#sorting in ascending order the correlation between outcom and otehr columsn for easy undersatnding

df.corr()['Outcome'].sort_values()
# Out:
#  BloodPressure               0.065068
# SkinThickness                0.074752
# Insulin                      0.130548
# DiabetiesPedegreeFunction    0.173844
# Pregnancies                  0.221898
# Age                          0.238356
# BMI                          0.292695
# Glucose                      0.466581
# Outcome                      1.000000
# Name: Outcome, dtype: float64

# %%
  #plotting heat map
sns.heatmap(df.corr(),annot=True, linewidths=0.5, linecolor='black',fmt= '.2f')
plt.figure(figsize=(15,7))

# %%
#corr between insulin & pregnacy is -0.07
#darker coloir means 0 corr.as corr increass it moves to the lighter color.
#negative corr says that if the value in 1 col increases the val in another colum decreases
#both +ve & -ve corr ahs an impact

# %% [markdown]
# Outcome of correlation

# %% [markdown]
# All the columns of the datasets are positively correlated with target column
#     1.Pregnancies has 22 percent correlation with the target column which can be considered as a good bond.
#     2.Glocose ash 47 per cent correlation with the target column which can be considered as a strong bond.
#     3. Blood pressure has a 7 per cent correlation with the target column which can be considered as a weak bond
#     4.skin thickness has a 7 percent correlation with the target column which can be considered as a weak bond.
#     5insulin has a 13 per cent correlation with the target column which can be considered as a good bond
#     6 BMI has a a29 per cent correlation with the target column which can be considered as a good bond
#     7.Diabetci pedigree function has a 29 per cent correlation with the target column which can be considered as a good bond
#     8.Age has a 24 per cent correlation with the target column which can be considered as a good bond
#
#     Max corr is glucose
#     min corr is skin thickness

# %% [markdown]
# Descriptive Statistics

# %% [markdown]
# Describing Datasets:

# %%
df.describe()
# Out:
#        Pregnancies     Glucose   BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000      768.000000     768.000000  768.000000
# mean      3.845052  120.894531       69.105469      20.536458   79.799479
# std       3.369578   31.972618       19.355807      15.952218  115.244002
# min       0.000000    0.000000        0.000000       0.000000    0.000000
# 25%       1.000000   99.000000       62.000000       0.000000    0.000000
# 50%       3.000000  117.000000       72.000000      23.000000   30.500000
# 75%       6.000000  140.250000       80.000000      32.000000  127.250000
# max      17.000000  199.000000      122.000000      99.000000  846.000000
#
#               BMI  DiabetiesPedegreeFunction         Age     Outcome
# count  768.000000                 768.000000  768.000000  768.000000
# mean    31.992578                   0.471876   33.240885    0.348958
# std      7.884160                   0.331329   11.760232    0.476951
# ...

# %%
#count is equal
mean gives column wise eman
std glucose std is widely distributed,insulin
min value column wise
25th percentile -25% f the data is covered
50 percentile -almost 50% of the dat lies under 3 
from min to max will say wheher there is skewness.in pregancy column 50% of the data lies within 3.
#and max is 17 so there is a skewness.if it was 4or 5 in 75 percentil & max then there wont eb any skewness
#it also shows higher no. have less frequency on pregancy column
#can sense ouliers,skewness, not normally distributed
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_11384/340390400.py", line 2
#     mean gives column wise eman
#          ^
# SyntaxError: invalid syntax

# %%
#since the 1st row count is equal is same in all the columns i am dropping it for analysing teh data

df.describe()[1:]
# Out:
#       Pregnancies     Glucose   BloodPressure  SkinThickness     Insulin  \
# mean     3.845052  120.894531       69.105469      20.536458   79.799479
# std      3.369578   31.972618       19.355807      15.952218  115.244002
# min      0.000000    0.000000        0.000000       0.000000    0.000000
# 25%      1.000000   99.000000       62.000000       0.000000    0.000000
# 50%      3.000000  117.000000       72.000000      23.000000   30.500000
# 75%      6.000000  140.250000       80.000000      32.000000  127.250000
# max     17.000000  199.000000      122.000000      99.000000  846.000000
#
#             BMI  DiabetiesPedegreeFunction        Age   Outcome
# mean  31.992578                   0.471876  33.240885  0.348958
# std    7.884160                   0.331329  11.760232  0.476951
# min    0.000000                   0.078000  21.000000  0.000000
# 25%   27.300000                   0.243750  24.000000  0.000000
# ...

# %%
#what if we had 100s of columns it wud be diff to analyse so we use transpose functions which will change rows to columsn & vice versa

df.describe()[1:].transpose()
# Out:
#                                  mean         std     min       25%       50%  \
# Pregnancies                  3.845052    3.369578   0.000   1.00000    3.0000
# Glucose                    120.894531   31.972618   0.000  99.00000  117.0000
#  BloodPressure              69.105469   19.355807   0.000  62.00000   72.0000
# SkinThickness               20.536458   15.952218   0.000   0.00000   23.0000
# Insulin                     79.799479  115.244002   0.000   0.00000   30.5000
# BMI                         31.992578    7.884160   0.000  27.30000   32.0000
# DiabetiesPedegreeFunction    0.471876    0.331329   0.078   0.24375    0.3725
# Age                         33.240885   11.760232  21.000  24.00000   29.0000
# Outcome                      0.348958    0.476951   0.000   0.00000    0.0000
#
#                                  75%     max
# Pregnancies                  6.00000   17.00
# Glucose                    140.25000  199.00
#  BloodPressure              80.00000  122.00
# ...

# %%
#now i dnrt want more than 2 decimal places so
round(df.describe()[1:].transpose(),2)
# Out:
#                              mean     std    min    25%     50%     75%  \
# Pregnancies                  3.85    3.37   0.00   1.00    3.00    6.00
# Glucose                    120.89   31.97   0.00  99.00  117.00  140.25
#  BloodPressure              69.11   19.36   0.00  62.00   72.00   80.00
# SkinThickness               20.54   15.95   0.00   0.00   23.00   32.00
# Insulin                     79.80  115.24   0.00   0.00   30.50  127.25
# BMI                         31.99    7.88   0.00  27.30   32.00   36.60
# DiabetiesPedegreeFunction    0.47    0.33   0.08   0.24    0.37    0.63
# Age                         33.24   11.76  21.00  24.00   29.00   41.00
# Outcome                      0.35    0.48   0.00   0.00    0.00    1.00
#
#                               max
# Pregnancies                 17.00
# Glucose                    199.00
#  BloodPressure             122.00
# SkinThickness               99.00
# Insulin                    846.00
# BMI                         67.10
# ...

# %%
#now we will plot the heat map of the describe()
#fmt means we want in floating values
#since we have rounded offf to 2 places the last digists afdter decimal is 000
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.savefig("heatmap.png")
plt.show()

# %% [markdown]
# # Outcome of the describe Dataset

# %%
From the above plotting we are determining the mean, standard deviation,minimum & maximum value of each column. It helps us further in data cleaning.
Total no. of rows in the dataset 
1.768 rows
2.9 columns

Pregnancies
Mean-3.845052
Std=3.369578
Max_values=17.00000
Min_values=0

Glucose
Mean=120.894531
Std=31.972618
Max_values=199.0000
Min_values=0

# %%
#this code helps to find the columns, datatype and memory used by the dataframe.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Pregnancies                768 non-null    int64
#  1   Glucose                    768 non-null    int64
#  2    BloodPressure             768 non-null    int64
#  3   SkinThickness              768 non-null    int64
#  4   Insulin                    768 non-null    int64
#  5   BMI                        768 non-null    float64
#  6   DiabetiesPedegreeFunction  768 non-null    float64
#  7   Age                        768 non-null    int64
#  8   Outcome                    768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#i am creating a variable to put all the columns
collist=df.columns.values
ncol=30
nrow=14
collist
# Out:
# array(['Pregnancies', 'Glucose', ' BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetiesPedegreeFunction', 'Age', 'Outcome'],
#       dtype=object)

# %% [markdown]
# Prerequisite of Every ML algorithm
#
# #data shud be normally distributed (skew=0),transformation 0.95*10^-23
# #data shud be in same range-normalization(min max scaler)/standardization(standard scaler)
# #no outliers-boxplot,zscore/IQR proximity rule=> if present the model trainign will be biased
# #no null values-Imputing (repalce,fillna,simple imputer,knn imputer)
# #standard normal distribution-standardization
# #(0.1)===> any ML algorithm, performs at its best find patterns

# %%
#for calculating skewnes the data column must be continuous
#skewness can be checked in categorical data but here the output is not correct as skewness can eb measured only with continuous data
#outliers also cnt be calculated on categorical data 
# hence transformation method cnt be applied to catogorical features
#outliers, skeweness & transformation method can be applied only to continuos data

# %%
#Dont calculate S.O.T on the target variable
Dnt disturb the target variable
skewness,outlier might end up dropping of data
encoding(label encoding)

# %%
df.skew()
# Out:
# Pregnancies                  0.901674
# Glucose                      0.173754
#  BloodPressure              -1.843608
# SkinThickness                0.109372
# Insulin                      2.272251
# BMI                         -0.428982
# DiabetiesPedegreeFunction    1.919911
# Age                          1.129597
# Outcome                      0.635017
# dtype: float64

# %%
Outcome of the skewness :Skewness threshold is taken as +/-.65,Columns which are having skewness
    Pregnancies
    Blood Pressure
    Insulin
    DiabetiesPedegreeFunction
    Age

# %% [markdown]
# Normal Distribution Curve

# %%
#We ahve to cehck individually every column to know the skewness presnt

sns.distplot(df['Pregnancies'])
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %% [markdown]
# There is skewness presnt here as its not the bell shape of a normal distribution. Hence need to apply transformation technique to reduce skewness.

# %%
sns.distplot(df['Glucose'])
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Density'>

# %% [markdown]
# The data is not normalised. The building blocks is out of the normalised curve.

# %%
sns.distplot(df[' BloodPressure'])
# Out:
# <AxesSubplot:xlabel=' BloodPressure', ylabel='Density'>

# %%
This has 2 modes. A data can have multiple modes but only 1 mean and median

# %%
sns.distplot(df['SkinThickness'])
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Density'>

# %% [markdown]
# This plot is almost bimodal=Two modes(most occuring frequency)

# %%
sns.distplot(df['BMI'])
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Density'>

# %%
sns.distplot(df['DiabetiesPedegreeFunction'])
# Out:
# <AxesSubplot:xlabel='DiabetiesPedegreeFunction', ylabel='Density'>

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# The normal distribution curve of outcome is irrelavant

# %% [markdown]
# Data cleaning: Here we will satrt bringing changes in the data based on all teh analysis & obervatiosn down till now

# %%
#checking the corr between outcome adn each indivudal colum

df.corr()['Outcome'].sort_values()
# Out:
#  BloodPressure               0.065068
# SkinThickness                0.074752
# Insulin                      0.130548
# DiabetiesPedegreeFunction    0.173844
# Pregnancies                  0.221898
# Age                          0.238356
# BMI                          0.292695
# Glucose                      0.466581
# Outcome                      1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# Outcome column is depended on Glucose  by 46%. This is the highest corr we are having for thsi particular set
# As Blood pressure (6.5%) & Skin Thickness is (7.4%) contribution only to the outcome we can remove these columsn adn see how the model is behaving

# %%
# to drop the 2 columns i am making anotehr datframe
delete=pd.DataFrame([['0.065068',' BloodPressure','No','Alot'],['0.074752','SkinThickness','No','Alot']],
                    columns=['Correlation with Target','Column Name','Normalised','Outlier'])
delete
# Out:
#   Correlation with Target     Column Name Normalised Outlier
# 0                0.065068   BloodPressure         No    Alot
# 1                0.074752   SkinThickness         No    Alot

# %% [markdown]
# Here we are setting the threshold of correlation as +-0.1.It is not standard. The dataset demands.

# %%
df=df.drop([' BloodPressure','SkinThickness'],axis=1)
df
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetiesPedegreeFunction  Age  \
# 0              6      148        0  33.6                      0.627   50
# 1              1       85        0  26.6                      0.351   31
# 2              8      183        0  23.3                      0.672   32
# 3              1       89       94  28.1                      0.167   21
# 4              0      137      168  43.1                      2.288   33
# ..           ...      ...      ...   ...                        ...  ...
# 763           10      101      180  32.9                      0.171   63
# 764            2      122        0  36.8                      0.340   27
# 765            5      121      112  26.2                      0.245   30
# 766            1      126        0  30.1                      0.349   47
# 767            1       93        0  30.4                      0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ...

# %%
df.shape
# Out:
# (768, 7)

# %% [markdown]
# Now to remove outliers:

# %% [markdown]
# Z-score technique

# %%
#If the data to be dropped as outliers is very high then i will try and bring it to the IQR proximity level.
#If the % of outliers is 5-7% i will drop it


from scipy.stats import zscore

# %%
#calculating zscore for every column
zscore(df)
# Out:
#      Pregnancies   Glucose   BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.848324        0.149641       0.907270 -0.692891  0.204013
# 1      -0.844885 -1.123396       -0.160546       0.530902 -0.692891 -0.684422
# 2       1.233880  1.943724       -0.263941      -1.288212 -0.692891 -1.103255
# 3      -0.844885 -0.998208       -0.160546       0.154533  0.123302 -0.494043
# 4      -1.141852  0.504055       -1.504687       0.907270  0.765836  1.409746
# ..           ...       ...             ...            ...       ...       ...
# 763     1.827813 -0.622642        0.356432       1.722735  0.870031  0.115169
# 764    -0.547919  0.034598        0.046245       0.405445 -0.692891  0.610154
# 765     0.342981  0.003301        0.149641       0.154533  0.279594 -0.735190
# 766    -0.844885  0.159787       -0.470732      -1.288212 -0.692891 -0.240205
# 767    -0.844885 -0.873019        0.046245       0.656358 -0.692891 -0.202129
#
# ...

# %%
#absolute(abs)function will convert any negative number into positive number
np.abs(-23)
# Out:
# 23

# %%
np.abs(23)
# Out:
# 23

# %%
z=np.abs(zscore(df))
z
# Out:
#      Pregnancies   Glucose   BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.848324        0.149641       0.907270  0.692891  0.204013
# 1       0.844885  1.123396        0.160546       0.530902  0.692891  0.684422
# 2       1.233880  1.943724        0.263941       1.288212  0.692891  1.103255
# 3       0.844885  0.998208        0.160546       0.154533  0.123302  0.494043
# 4       1.141852  0.504055        1.504687       0.907270  0.765836  1.409746
# ..           ...       ...             ...            ...       ...       ...
# 763     1.827813  0.622642        0.356432       1.722735  0.870031  0.115169
# 764     0.547919  0.034598        0.046245       0.405445  0.692891  0.610154
# 765     0.342981  0.003301        0.149641       0.154533  0.279594  0.735190
# 766     0.844885  0.159787        0.470732       1.288212  0.692891  0.240205
# 767     0.844885  0.873019        0.046245       0.656358  0.692891  0.202129
#
# ...

# %%
z.shape
# Out:
# (768, 7)

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
#this command will give the output as the index(where) which has outliers
np.where(z>3)
# Out:
# (array([  4,   8,   9,  13,  45,  49,  58,  60,  75,  81,  88, 111, 123,
#         145, 153, 159, 177, 182, 186, 220, 228, 228, 247, 286, 298, 330,
#         342, 349, 370, 370, 371, 371, 395, 409, 415, 426, 445, 445, 453,
#         455, 459, 486, 494, 502, 522, 584, 593, 621, 645, 655, 666, 673,
#         684, 684, 695, 706, 753], dtype=int64),
#  array([4, 2, 3, 2, 4, 3, 4, 3, 1, 3, 0, 2, 5, 3, 2, 0, 3, 1, 2, 2, 2, 4,
#         2, 2, 0, 4, 1, 1, 2, 4, 3, 4, 4, 2, 2, 3, 3, 4, 5, 0, 5, 2, 3, 1,
#         3, 2, 4, 4, 2, 2, 5, 3, 3, 5, 2, 3, 2], dtype=int64))

# %%
#in row 4 column 4 there is an outlier, in

# %%
z.iloc[4]
# Out:
# Pregnancies                  1.141852
# Glucose                      0.504055
# Insulin                      0.765836
# BMI                          1.409746
# DiabetiesPedegreeFunction    5.484909
# Age                          0.020496
# Outcome                      1.365896
# Name: 4, dtype: float64

# %%
#In row 8 index column 2 has an outlier
z.iloc[8]
# Out:
# Pregnancies                  0.547919
# Glucose                      2.381884
# Insulin                      4.021922
# BMI                          0.189437
# DiabetiesPedegreeFunction    0.947944
# Age                          1.681259
# Outcome                      1.365896
# Name: 8, dtype: float64

# %%
#to know the total number of rows with outliers
len(np.where(z>3)[0])
# Out:
# 57

# %% [markdown]
# as it si 7% of the total dataset,i am droppign the outliers

# %%
In numpy
row=axis=1
column=axis=0

Pandas
row=axis=0
column=axis=1

# %%
#now going to use pandas slicing method to drop the outliers. We will move to another dataframe so that orginal data is not lost
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148              72             35        0  33.6
# 1              1       85              66             29        0  26.6
# 2              8      183              64              0        0  23.3
# 3              1       89              66             23       94  28.1
# 5              5      116              74              0        0  25.6
# ..           ...      ...             ...            ...      ...   ...
# 763           10      101              76             48      180  32.9
# 764            2      122              70             27        0  36.8
# 765            5      121              72             23      112  26.2
# 766            1      126              60              0        0  30.1
# 767            1       93              70             31        0  30.4
#
#      DiabetiesPedegreeFunction  Age  Outcome
# 0                        0.627   50        1
# ...

# %%
print("Old Dataframe",df.shape)
print("New Dataframe",df_new.shape)
print("Total dropped Dataframe",df.shape[0]-df_new.shape[0])
# Out:
# Old Dataframe (768, 7)
# New Dataframe (716, 7)
# Total dropped Dataframe 52

# %% [markdown]
# # Seperate the data

# %%
#independednt variables
x=df_new.iloc[:,:-1]
x
# Out:
#      Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148              72             35        0  33.6
# 1              1       85              66             29        0  26.6
# 2              8      183              64              0        0  23.3
# 3              1       89              66             23       94  28.1
# 5              5      116              74              0        0  25.6
# ..           ...      ...             ...            ...      ...   ...
# 763           10      101              76             48      180  32.9
# 764            2      122              70             27        0  36.8
# 765            5      121              72             23      112  26.2
# 766            1      126              60              0        0  30.1
# 767            1       93              70             31        0  30.4
#
#      DiabetiesPedegreeFunction  Age
# 0                        0.627   50
# ...

# %%
y=df_new.iloc[:,-1]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 5      0
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 688, dtype: int64

# %% [markdown]
# Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform

# %%
# 2 methods of transfroamton
#1. yeo -Johnson by default(both positive & negatoive data)
#2.box cox-it has to be mentioned. condition is that the data has to be positive.

x=power_transform(x,method= 'yeo-johnson')

# %%
type(x)
# Out:
# numpy.ndarray

# %%
#output is numpy coz whenevr we do preprocessing the output will be numpy even though the input is in pandas dataframe
x
# Out:
# array([[ 0.81766344,  0.95218058, -1.00223104,  0.28114356,  0.86495337,
#          1.39031405],
#        [-0.84957557, -1.28238174, -1.00223104, -0.83047682, -0.16002044,
#          0.12808007],
#        [ 1.20277392,  1.82893792, -1.00223104, -1.43279399,  0.98450779,
#          0.23328673],
#        ...,
#        [ 0.59040907,  0.13114807,  0.96157194, -0.9003888 , -0.75346236,
#          0.0156547 ],
#        [-0.84957557,  0.29534181, -1.00223104, -0.25021575, -0.1698999 ,
#          1.26101626],
#        [-0.84957557, -0.92550642, -1.00223104, -0.2028927 , -0.34504064,
#         -1.05311184]])

# %%
#this is a 2 dimensonal array. it can be knows bybthe no. of square brackets in the begining.
#ML will accept only 2 dimensional data.
x.ndim
# Out:
# 2

# %% [markdown]
# #standardisation is already done when power_transform has been applied.

# %%
x.mean()
# Out:
# 2.395972929679877e-15

# %%
round(x.mean(),2)
# Out:
# 0.0

# %%
x.std()
# Out:
# 1.0

# %% [markdown]
# Since the outcome has only 2 classes yes diabteic and no diabeties we will use binary classification model

# %% [markdown]
# Anaysis on output column

# %%
#to knw the no. of outputs 
df_new.Outcome.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df_new.Outcome.value_counts()
# Out:
# 0    461
# 1    227
# Name: Outcome, dtype: int64

# %% [markdown]
# Now we have to equalise the outputs 0 and 1 rows
# Non diabetic is 0
# Diabetic is 1
# Its an imbalanced dataset

# %%
Balancing techniques
Over sampling-SMOTE, Adasym (getting the data equal to the highest one eg. 1 is 500.1 is 268.
so 1 has to be brought to 500)
undersampling-will match the frequency of the lower no. 268=268
random oversampling-
stacking-combination of oversampling & undersampling
https://imbalanced-learn.org/stable/

# %% [markdown]
# Importing SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()

# %%
#x,y are the inputs inside smote to create artificial rows
#trainx & trainy are givng the new rows
trainx,trainy=smt.fit_resample(x,y)

# %%
trainx.value_counts()
# Out:
# Pregnancies  Glucose   BloodPressure  SkinThickness  Insulin  BMI        DiabetiesPedegreeFunction  Age
# 0            57       60              0              0        21.700000  0.735000                   67     1
# 5            139      80              35             160      31.600000  0.361000                   25     1
#              144      82              26             285      32.000000  0.452000                   58     1
#              147      75              0              0        29.900000  0.434000                   28     1
#                       78              0              0        33.700000  0.218000                   65     1
#                                                                                                           ..
# 2            111      60              0              0        26.200000  0.343000                   23     1
#              112      66              22             0        25.000000  0.307000                   24     1
# ...

# %%
trainx.shape
# Out:
# (922, 8)

# %%
trainy.value_counts()
# Out:
# 1    461
# 0    461
# Name: Outcome, dtype: int64

# %%
trainy.shape
# Out:
# (922,)

# %% [markdown]
# Model-Linear Regression czo ylable is binary

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lr=LogisticRegression()
for i in range(0,1000):
    x_train,y_train,x_test,y_test=train_test_split(trainx,trainy,random_state=i,test_size=.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.preditc(x_test)
    #if both training & testing acc are same it will print
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state",i,"The model performs well")
        print("At random_state:-",i)
        print("Training accuracy score is:-", round(accuracy_score(y_train,pred_train)*100,1))
        print("Testing accuracy score is:-", round(accuracy_score(y_test,pred_test)*100,1),'\n\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2796/3810212164.py in <module>
#       2 for i in range(0,1000):
#       3     x_train,y_train,x_test,y_test=train_test_split(trainx,trainy,random_state=i,test_size=.20)
# ----> 4     lr.fit(x_train,y_train)
#       5     pred_train=lr.predict(x_train)
#       6     pred_test=lr.preditc(x_test)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1136             _dtype = [np.float64, np.float32]
#    1137
# -> 1138         X, y = self._validate_data(
#    1139             X,
#    1140             y,
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
# ...

# %%
x_train.shape
# Out:
# (737, 8)

# %%
y_train.shape
# Out:
# (185, 8)
